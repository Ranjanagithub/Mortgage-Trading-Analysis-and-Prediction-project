# %%
##Importing the necessary libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
## Importing the dataset
df=pd.read_csv('/content/LoanExport.csv')

df.head()
# Out:
# <ipython-input-3-f65e6fe0882a>:2: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('/content/LoanExport.csv')
#    CreditScore  FirstPaymentDate FirstTimeHomebuyer  MaturityDate    MSA  MIP  \
# 0            0            199902                  N        202901  16974   25
# 1            0            199902                  N        202901  19740    0
# 2            0            199902                  N        202901  29940    0
# 3            0            199902                  N        202901  31084    0
# 4            0            199902                  N        202901  35644    0
#
#    Units Occupancy  OCLTV  DTI  ...  PostalCode    LoanSeqNum  LoanPurpose  \
# 0      1         O     89   27  ...       60400  F199Q1268030            P
# 1      1         O     73   17  ...       80200  F199Q1015092            N
# 2      1         O     75   16  ...       66000  F199Q1266886            N
# 3      1         O     76   14  ...       90700  F199Q1178167            N
# 4      1         O     78   18  ...        7600  F199Q1178517            N
#
#   OrigLoanTerm NumBorrowers SellerName          ServicerName EverDelinquent  \
# 0          360            2         FL  WASHINGTONMUTUALBANK              0
# 1          360            1         FT  CHASEHOMEFINANCELLC               0
# 2          360            2         FL  WASHINGTONMUTUALBANK              0
# 3          360            2         GM  GMACMTGECORP                      0
# 4          360            2         GM  GMACMTGECORP                      0
#
#   MonthsDelinquent MonthsInRepayment
# 0                0                52
# 1                0               144
# 2                0                67
# 3                0                35
# 4                0                54
#
# [5 rows x 28 columns]

# %%
## Basic information displayed
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 291451 entries, 0 to 291450
# Data columns (total 28 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   CreditScore         291451 non-null  int64
#  1   FirstPaymentDate    291451 non-null  int64
#  2   FirstTimeHomebuyer  291451 non-null  object
#  3   MaturityDate        291451 non-null  int64
#  4   MSA                 291451 non-null  object
#  5   MIP                 291451 non-null  int64
#  6   Units               291451 non-null  int64
#  7   Occupancy           291451 non-null  object
#  8   OCLTV               291451 non-null  int64
#  9   DTI                 291451 non-null  int64
#  10  OrigUPB             291451 non-null  int64
#  11  LTV                 291451 non-null  int64
#  12  OrigInterestRate    291451 non-null  float64
#  13  Channel             291451 non-null  object
#  14  PPM                 291451 non-null  object
#  15  ProductType         291451 non-null  object
#  16  PropertyState       291451 non-null  object
#  17  PropertyType        291451 non-null  object
#  18  PostalCode          291451 non-null  object
#  19  LoanSeqNum          291451 non-null  object
#  20  LoanPurpose         291451 non-null  object
#  21  OrigLoanTerm        291451 non-null  int64
#  22  NumBorrowers        291451 non-null  object
#  23  SellerName          266457 non-null  object
#  24  ServicerName        291451 non-null  object
#  25  EverDelinquent      291451 non-null  int64
#  26  MonthsDelinquent    291451 non-null  int64
#  27  MonthsInRepayment   291451 non-null  int64
# dtypes: float64(1), int64(13), object(14)
# memory usage: 62.3+ MB

# %%
### Summary statistics of the dataset
df.describe()
# Out:
#          CreditScore  FirstPaymentDate   MaturityDate            MIP  \
# count  291451.000000     291451.000000  291451.000000  291451.000000
# mean      708.936991     199904.760553  202902.367043       9.216685
# std        68.408791         13.821228      16.090508      12.648273
# min         0.000000     199901.000000  202402.000000       0.000000
# 25%       675.000000     199903.000000  202902.000000       0.000000
# 50%       717.000000     199904.000000  202903.000000       0.000000
# 75%       753.000000     199905.000000  202904.000000      25.000000
# max       849.000000     201303.000000  204302.000000      55.000000
#
#                Units          OCLTV            DTI        OrigUPB  \
# count  291451.000000  291451.000000  291451.000000  291451.000000
# mean        1.026022      76.960529      30.033453  124940.387921
# std         0.202986      15.236154      13.203974   53657.440624
# min         0.000000       0.000000       0.000000    8000.000000
# 25%         1.000000      70.000000      22.000000   83000.000000
# 50%         1.000000      80.000000      31.000000  117000.000000
# 75%         1.000000      90.000000      39.000000  160000.000000
# max         4.000000     110.000000      65.000000  497000.000000
#
#                  LTV  OrigInterestRate   OrigLoanTerm  EverDelinquent  \
# count  291451.000000     291451.000000  291451.000000   291451.000000
# mean       76.937986          6.926547     359.835375        0.197848
# std        15.225298          0.343541       2.286939        0.398378
# min         0.000000          4.000000     301.000000        0.000000
# 25%        70.000000          6.750000     360.000000        0.000000
# 50%        80.000000          6.875000     360.000000        0.000000
# 75%        90.000000          7.125000     360.000000        0.000000
# max       103.000000         12.350000     361.000000        1.000000
#
#        MonthsDelinquent  MonthsInRepayment
# count     291451.000000      291451.000000
# mean           1.837729          60.805291
# std            8.809392          46.142599
# min            0.000000           1.000000
# 25%            0.000000          34.000000
# 50%            0.000000          48.000000
# 75%            0.000000          63.000000
# max          180.000000         212.000000

# %%
# Check for missing values in the entire DataFrame
df.isnull()
# Out:
#         CreditScore  FirstPaymentDate  FirstTimeHomebuyer  MaturityDate  \
# 0             False             False               False         False
# 1             False             False               False         False
# 2             False             False               False         False
# 3             False             False               False         False
# 4             False             False               False         False
# ...             ...               ...                 ...           ...
# 291446        False             False               False         False
# 291447        False             False               False         False
# 291448        False             False               False         False
# 291449        False             False               False         False
# 291450        False             False               False         False
#
#           MSA    MIP  Units  Occupancy  OCLTV    DTI  ...  PostalCode  \
# 0       False  False  False      False  False  False  ...       False
# 1       False  False  False      False  False  False  ...       False
# 2       False  False  False      False  False  False  ...       False
# 3       False  False  False      False  False  False  ...       False
# 4       False  False  False      False  False  False  ...       False
# ...       ...    ...    ...        ...    ...    ...  ...         ...
# 291446  False  False  False      False  False  False  ...       False
# 291447  False  False  False      False  False  False  ...       False
# 291448  False  False  False      False  False  False  ...       False
# 291449  False  False  False      False  False  False  ...       False
# 291450  False  False  False      False  False  False  ...       False
#
#         LoanSeqNum  LoanPurpose  OrigLoanTerm  NumBorrowers  SellerName  \
# 0            False        False         False         False       False
# 1            False        False         False         False       False
# 2            False        False         False         False       False
# 3            False        False         False         False       False
# 4            False        False         False         False       False
# ...            ...          ...           ...           ...         ...
# 291446       False        False         False         False       False
# 291447       False        False         False         False       False
# 291448       False        False         False         False       False
# 291449       False        False         False         False       False
# 291450       False        False         False         False       False
#
#         ServicerName  EverDelinquent  MonthsDelinquent  MonthsInRepayment
# 0              False           False             False              False
# 1              False           False             False              False
# 2              False           False             False              False
# 3              False           False             False              False
# 4              False           False             False              False
# ...              ...             ...               ...                ...
# 291446         False           False             False              False
# 291447         False           False             False              False
# 291448         False           False             False              False
# 291449         False           False             False              False
# 291450         False           False             False              False
#
# [291451 rows x 28 columns]

# %%
## Summarize the number of missing values in each column
df.isnull().sum()
# Out:
# CreditScore               0
# FirstPaymentDate          0
# FirstTimeHomebuyer        0
# MaturityDate              0
# MSA                       0
# MIP                       0
# Units                     0
# Occupancy                 0
# OCLTV                     0
# DTI                       0
# OrigUPB                   0
# LTV                       0
# OrigInterestRate          0
# Channel                   0
# PPM                       0
# ProductType               0
# PropertyState             0
# PropertyType              0
# PostalCode                0
# LoanSeqNum                0
# LoanPurpose               0
# OrigLoanTerm              0
# NumBorrowers              0
# SellerName            24994
# ServicerName              0
# EverDelinquent            0
# MonthsDelinquent          0
# MonthsInRepayment         0
# dtype: int64

# %%
# Check for duplicates in each column
for column in df.columns:
    if df[column].duplicated().any():
        print(f"Column '{column}' has duplicate values.")
    else:
        print(f"Column '{column}' does not have duplicate values.")
# Out:
# Column 'CreditScore' has duplicate values.
# Column 'FirstPaymentDate' has duplicate values.
# Column 'FirstTimeHomebuyer' has duplicate values.
# Column 'MaturityDate' has duplicate values.
# Column 'MSA' has duplicate values.
# Column 'MIP' has duplicate values.
# Column 'Units' has duplicate values.
# Column 'Occupancy' has duplicate values.
# Column 'OCLTV' has duplicate values.
# Column 'DTI' has duplicate values.
# Column 'OrigUPB' has duplicate values.
# Column 'LTV' has duplicate values.
# Column 'OrigInterestRate' has duplicate values.
# Column 'Channel' has duplicate values.
# Column 'PPM' has duplicate values.
# Column 'ProductType' has duplicate values.
# Column 'PropertyState' has duplicate values.
# Column 'PropertyType' has duplicate values.
# Column 'PostalCode' has duplicate values.
# Column 'LoanSeqNum' does not have duplicate values.
# Column 'LoanPurpose' has duplicate values.
# Column 'OrigLoanTerm' has duplicate values.
# Column 'NumBorrowers' has duplicate values.
# Column 'SellerName' has duplicate values.
# Column 'ServicerName' has duplicate values.
# Column 'EverDelinquent' has duplicate values.
# Column 'MonthsDelinquent' has duplicate values.
# Column 'MonthsInRepayment' has duplicate values.

# %%
import matplotlib.pyplot as plt

# Calculate the number of duplicates in each column
duplicate_counts = df.apply(lambda x: x.duplicated().sum())

# Plot the results
duplicate_counts.plot(kind='bar', figsize=(12, 6))
plt.title('Number of Duplicate Values in Each Column')
plt.ylabel('Number of Duplicates')
plt.show()

# %%
# Apply drop_duplicates to each column
df_cleaned = df.apply(lambda x: x.drop_duplicates().reset_index(drop=True))

print(df_cleaned)
# Out:
#         CreditScore  FirstPaymentDate FirstTimeHomebuyer  MaturityDate    MSA  \
# 0               0.0          199902.0                  N      202901.0  16974
# 1             335.0          199903.0                  X      202710.0  19740
# 2             342.0          199904.0                  Y      202902.0  29940
# 3             363.0          199905.0                NaN      202409.0  31084
# 4             366.0          199906.0                NaN      202702.0  35644
# ...             ...               ...                ...           ...    ...
# 291446          NaN               NaN                NaN           NaN    NaN
# 291447          NaN               NaN                NaN           NaN    NaN
# 291448          NaN               NaN                NaN           NaN    NaN
# 291449          NaN               NaN                NaN           NaN    NaN
# 291450          NaN               NaN                NaN           NaN    NaN
#
#          MIP  Units Occupancy  OCLTV   DTI  ...  PostalCode    LoanSeqNum  \
# 0       25.0    1.0         O   89.0  27.0  ...       60400  F199Q1268030
# 1        0.0    2.0         I   73.0  17.0  ...       80200  F199Q1015092
# 2       30.0    4.0         S   75.0  16.0  ...       66000  F199Q1266886
# 3       12.0    3.0       NaN   76.0  14.0  ...       90700  F199Q1178167
# 4       35.0    0.0       NaN   78.0  18.0  ...        7600  F199Q1178517
# ...      ...    ...       ...    ...   ...  ...         ...           ...
# 291446   NaN    NaN       NaN    NaN   NaN  ...         NaN  F199Q1220925
# 291447   NaN    NaN       NaN    NaN   NaN  ...         NaN  F199Q1401332
# 291448   NaN    NaN       NaN    NaN   NaN  ...         NaN  F199Q1401282
# 291449   NaN    NaN       NaN    NaN   NaN  ...         NaN  F199Q1220924
# 291450   NaN    NaN       NaN    NaN   NaN  ...         NaN  F199Q1220923
#
#         LoanPurpose OrigLoanTerm NumBorrowers SellerName  \
# 0                 P        360.0            2         FL
# 1                 N        345.0            1         FT
# 2                 C        306.0           X          GM
# 3               NaN        335.0          NaN         Ot
# 4               NaN        322.0          NaN         RE
# ...             ...          ...          ...        ...
# 291446          NaN          NaN          NaN        NaN
# 291447          NaN          NaN          NaN        NaN
# 291448          NaN          NaN          NaN        NaN
# 291449          NaN          NaN          NaN        NaN
# 291450          NaN          NaN          NaN        NaN
#
#                 ServicerName EverDelinquent MonthsDelinquent MonthsInRepayment
# 0       WASHINGTONMUTUALBANK            0.0              0.0              52.0
# 1       CHASEHOMEFINANCELLC             1.0              3.0             144.0
# 2       GMACMTGECORP                    NaN            104.0              67.0
# 3       Other servicers                 NaN              5.0              35.0
# 4        WELLSFARGOBANKNA               NaN             23.0              54.0
# ...                      ...            ...              ...               ...
# 291446                   NaN            NaN              NaN               NaN
# 291447                   NaN            NaN              NaN               NaN
# 291448                   NaN            NaN              NaN               NaN
# 291449                   NaN            NaN              NaN               NaN
# 291450                   NaN            NaN              NaN               NaN
#
# [291451 rows x 28 columns]

# %%
df['SellerName'].isnull().sum()
# Out:
# 24994

# %%
df['SellerName'].mode().values[0]
# Out:
# 'Ot'

# %%
df['SellerName'] = df['SellerName'].fillna(df['SellerName'].dropna().mode().values[0])

# %%
df['SellerName'].isnull().sum()
# Out:
# 0

# %%
df.FirstTimeHomebuyer.shape
# Out:
# (291451,)

# %%
df['FirstTimeHomebuyer'].value_counts()
# Out:
# FirstTimeHomebuyer
# N    184154
# X     78015
# Y     29282
# Name: count, dtype: int64

# %%
df['FirstTimeHomebuyer'].sort_values()
# Out:
# 0         N
# 173805    N
# 173806    N
# 173807    N
# 173808    N
#          ..
# 154817    Y
# 154816    Y
# 154815    Y
# 212120    Y
# 194891    Y
# Name: FirstTimeHomebuyer, Length: 291451, dtype: object

# %%
df =  df[df["FirstTimeHomebuyer"]!= 'X']

# %%
df["FirstTimeHomebuyer"]
# Out:
# 0         N
# 1         N
# 2         N
# 3         N
# 4         N
#          ..
# 291446    N
# 291447    N
# 291448    N
# 291449    N
# 291450    N
# Name: FirstTimeHomebuyer, Length: 213436, dtype: object

# %%
df["FirstTimeHomebuyer"].value_counts()
# Out:
# FirstTimeHomebuyer
# N    184154
# Y     29282
# Name: count, dtype: int64

# %%
df.FirstTimeHomebuyer.shape
# Out:
# (213436,)

# %%
df['PPM'].value_counts()
# Out:
# PPM
# N    204660
# X      4895
# Y      3881
# Name: count, dtype: int64

# %%
df =df[df['PPM']!='X']

# %%
df['PPM'].value_counts()
# Out:
# PPM
# N    204660
# Y      3881
# Name: count, dtype: int64

# %%
df.PropertyType.dtypes
# Out:
# dtype('O')

# %%
df.PropertyType.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 208541 entries, 0 to 291450
# Series name: PropertyType
# Non-Null Count   Dtype
# --------------   -----
# 208541 non-null  object
# dtypes: object(1)
# memory usage: 3.2+ MB

# %%
df.PropertyType.value_counts()
# Out:
# PropertyType
# SF    171892
# PU     22726
# CO     13325
# MH       462
# CP        61
# LH        54
# X         21
# Name: count, dtype: int64

# %%
df =df[df['PropertyType']!='X']

# %%
df=df[df["PropertyType"]!= "X"]

# %%
df.MSA.shape
# Out:
# (208541,)

# %%
df.MSA.value_counts()
# Out:
# MSA
# X        26716
# 31084     7114
# 16974     6495
# 12060     5094
# 47644     5050
#          ...
# 41900        3
# 49500        2
# 10380        1
# 25020        1
# 32420        1
# Name: count, Length: 392, dtype: int64

# %%
df['MSA'] = pd.to_numeric(df['MSA'], errors='coerce').fillna(0).astype(int)

# %%
df = df[df['MSA'] != 0]

# %%
df.MSA.shape
# Out:
# (181825,)

# %%
df['MSA'].value_counts()
# Out:
# MSA
# 31084    7114
# 16974    6495
# 12060    5094
# 47644    5050
# 38060    4388
#          ...
# 41900       3
# 49500       2
# 10380       1
# 25020       1
# 32420       1
# Name: count, Length: 391, dtype: int64

# %%
df['MSA'].sort_values(ascending=False)
# Out:
# 119448    49740
# 228853    49740
# 120551    49740
# 195967    49740
# 254829    49740
#           ...
# 273197    10180
# 223356    10180
# 169221    10180
# 87483     10180
# 139317    10180
# Name: MSA, Length: 181825, dtype: int64

# %%
df.isnull().sum()
# Out:
# CreditScore           0
# FirstPaymentDate      0
# FirstTimeHomebuyer    0
# MaturityDate          0
# MSA                   0
# MIP                   0
# Units                 0
# Occupancy             0
# OCLTV                 0
# DTI                   0
# OrigUPB               0
# LTV                   0
# OrigInterestRate      0
# Channel               0
# PPM                   0
# ProductType           0
# PropertyState         0
# PropertyType          0
# PostalCode            0
# LoanSeqNum            0
# LoanPurpose           0
# OrigLoanTerm          0
# NumBorrowers          0
# SellerName            0
# ServicerName          0
# EverDelinquent        0
# MonthsDelinquent      0
# MonthsInRepayment     0
# dtype: int64

# %%
df.NumBorrowers.shape
# Out:
# (181825,)

# %%
df.NumBorrowers.dtypes
# Out:
# dtype('O')

# %%
df.NumBorrowers.value_counts()
# Out:
# NumBorrowers
# 2     115165
# 1      66521
# X        139
# Name: count, dtype: int64

# %%
df['NumBorrowers'] = pd.to_numeric(df['NumBorrowers'], errors='coerce').fillna(0).astype(int)

# %%
df = df[df['NumBorrowers']!= 0]

# %%
df.NumBorrowers.value_counts()
# Out:
# NumBorrowers
# 2    115165
# 1     66521
# Name: count, dtype: int64

# %%
df.NumBorrowers.shape
# Out:
# (181686,)

# %%
df.NumBorrowers.dtypes
# Out:
# dtype('int64')

# %%
df.isnull().sum()
# Out:
# CreditScore           0
# FirstPaymentDate      0
# FirstTimeHomebuyer    0
# MaturityDate          0
# MSA                   0
# MIP                   0
# Units                 0
# Occupancy             0
# OCLTV                 0
# DTI                   0
# OrigUPB               0
# LTV                   0
# OrigInterestRate      0
# Channel               0
# PPM                   0
# ProductType           0
# PropertyState         0
# PropertyType          0
# PostalCode            0
# LoanSeqNum            0
# LoanPurpose           0
# OrigLoanTerm          0
# NumBorrowers          0
# SellerName            0
# ServicerName          0
# EverDelinquent        0
# MonthsDelinquent      0
# MonthsInRepayment     0
# dtype: int64

# %%
df["IsFirstTimeHomebuyer"] = df['FirstTimeHomebuyer'].map({"N":0,"Y":1})
df.head()
# Out:
#    CreditScore  FirstPaymentDate FirstTimeHomebuyer  MaturityDate    MSA  MIP  \
# 0            0            199902                  N        202901  16974   25
# 1            0            199902                  N        202901  19740    0
# 2            0            199902                  N        202901  29940    0
# 3            0            199902                  N        202901  31084    0
# 4            0            199902                  N        202901  35644    0
#
#    Units Occupancy  OCLTV  DTI  ...    LoanSeqNum  LoanPurpose  OrigLoanTerm  \
# 0      1         O     89   27  ...  F199Q1268030            P           360
# 1      1         O     73   17  ...  F199Q1015092            N           360
# 2      1         O     75   16  ...  F199Q1266886            N           360
# 3      1         O     76   14  ...  F199Q1178167            N           360
# 4      1         O     78   18  ...  F199Q1178517            N           360
#
#   NumBorrowers SellerName          ServicerName EverDelinquent  \
# 0            2         FL  WASHINGTONMUTUALBANK              0
# 1            1         FT  CHASEHOMEFINANCELLC               0
# 2            2         FL  WASHINGTONMUTUALBANK              0
# 3            2         GM  GMACMTGECORP                      0
# 4            2         GM  GMACMTGECORP                      0
#
#   MonthsDelinquent MonthsInRepayment IsFirstTimeHomebuyer
# 0                0                52                    0
# 1                0               144                    0
# 2                0                67                    0
# 3                0                35                    0
# 4                0                54                    0
#
# [5 rows x 29 columns]

# %%
df['IsFirstTimeHomebuyer'].unique()
# Out:
# array([0, 1])

# %%
df['LTV_Range'] = ""
for index, value in df['LTV'].items():  # Use items() instead of iteritems()
    if value >= 0 and value < 25:
        df.at[index, 'LTV_Range'] = 'Low'
    elif value >= 25 and value < 50:
        df.at[index, 'LTV_Range'] = 'Medium'
    elif value >= 50 and value < 75:
        df.at[index, 'LTV_Range'] = 'High'
    elif value >= 75 and value <= 100:
        df.at[index, 'LTV_Range'] = 'Very High'
    else:
        df.at[index, 'LTV_Range'] = 'Invalid value'

# %%
df['LTV'].value_counts().index
# Out:
# Index([ 80,  95,  90,  75,  85,  79,  97,  78,  70,  74,  77,  73,  89,  72,
#         76,  69,  71,  88,  65,  67,  68,  87,  66,  64,  60,  63,  84,  62,
#         56,  86,  59,  93,  57,  61,  55,  94,  50,  83,  54,  53,  58,  92,
#         52,  48,  49,  51,  47,  82,  45,  46,  44,  43,  40,  42,  39,  38,
#         41,  37,  91,  34,  35,  36,  30,  33,  32,  28,  81,  31,  27,  24,
#         25,  26,  29,  23,  22,  96,  20,  21,  19,  18,  17,  16,  15,  14,
#         13,  12,   9,  11, 100,  10,   8,   7,  98,   6,   0],
#       dtype='int64', name='LTV')

# %%
df['CreditRange'] = ""
for index, value in df['CreditScore'].items():
    if value >= 0 and value < 650:
        df.at[index, 'CreditRange'] = 'Poor'
    elif value >= 650 and value < 700:
        df.at[index, 'CreditRange'] = 'Fair'
    elif value >= 700 and value < 750:
        df.at[index, 'CreditRange'] = 'Good'
    elif value >= 750 and value <= 900:
        df.at[index, 'CreditRange'] = 'Excellent'
    else:
        df.at[index, 'CreditRange'] = 'Invalid value'

# %%
df['MIP_Range'] = ""

for index, value in df['MIP'].items():
    if value >= 0 and value < 25:
        df.at[index, 'MIP_Range'] = 'Low'
    elif value >= 25 and value < 50:
        df.at[index, 'MIP_Range'] = 'Medium'
    elif value >= 50 and value < 75:
        df.at[index, 'MIP_Range'] = 'High'
    else:
        df.at[index, 'MIP_Range'] = 'Invalid value'

# %%
df['MIP'].value_counts()
# Out:
# MIP
# 0     107317
# 30     33430
# 25     26832
# 12      7212
# 18      2443
# 17      1660
# 35      1004
# 36       678
# 29       581
# 20       228
# 14       145
# 27        49
# 22        26
# 6         16
# 33        12
# 50         7
# 28         6
# 47         5
# 26         5
# 1          4
# 16         4
# 32         4
# 24         3
# 13         3
# 15         2
# 37         2
# 10         2
# 55         1
# 21         1
# 11         1
# 7          1
# 52         1
# 4          1
# Name: count, dtype: int64

# %%
df['RepPayRange'] = ""
for index, value in df['MonthsInRepayment'].items():
    if value >= 0 and value < 48:
        df.at[index, 'RepPayRange'] = '0-4yrs'
    elif value >= 48 and value < 96:
        df.at[index, 'RepPayRange'] = '4-8yrs'
    elif value >= 96 and value < 144:
        df.at[index, 'RepPayRange'] = '8-12yrs'
    elif value >= 144 and value < 192:
        df.at[index, 'RepPayRange'] = '12-16yrs'
    elif value >= 192 and value < 240:
        df.at[index, 'RepPayRange'] = '16-20yrs'
    else:
        df.at[index, 'RepPayRange'] = 'Invalid value'

# %%
df["RepPayRange"].value_counts()
# Out:
# RepPayRange
# 0-4yrs      89448
# 4-8yrs      67169
# 8-12yrs     11180
# 12-16yrs     7319
# 16-20yrs     6570
# Name: count, dtype: int64

# %%
df.head(100000)
# Out:
#         CreditScore  FirstPaymentDate FirstTimeHomebuyer  MaturityDate    MSA  \
# 0                 0            199902                  N        202901  16974
# 1                 0            199902                  N        202901  19740
# 2                 0            199902                  N        202901  29940
# 3                 0            199902                  N        202901  31084
# 4                 0            199902                  N        202901  35644
# ...             ...               ...                ...           ...    ...
# 161128          725            199904                  Y        202903  16740
# 161129          725            199904                  Y        202903  16974
# 161130          725            199904                  Y        202903  17140
# 161131          725            199904                  Y        202903  18140
# 161132          725            199904                  Y        202903  22660
#
#         MIP  Units Occupancy  OCLTV  DTI  ...  SellerName  \
# 0        25      1         O     89   27  ...          FL
# 1         0      1         O     73   17  ...          FT
# 2         0      1         O     75   16  ...          FL
# 3         0      1         O     76   14  ...          GM
# 4         0      1         O     78   18  ...          GM
# ...     ...    ...       ...    ...  ...  ...         ...
# 161128    0      1         O     79   33  ...          FI
# 161129    0      1         O     94    0  ...          ST
# 161130   30      1         O     95   36  ...          Ot
# 161131    0      1         O     80   36  ...          NO
# 161132    0      1         O     80   30  ...          CO
#
#                 ServicerName  EverDelinquent MonthsDelinquent  \
# 0       WASHINGTONMUTUALBANK               0                0
# 1       CHASEHOMEFINANCELLC                0                0
# 2       WASHINGTONMUTUALBANK               0                0
# 3       GMACMTGECORP                       0                0
# 4       GMACMTGECORP                       0                0
# ...                      ...             ...              ...
# 161128   WELLSFARGOBANKNA                  0                0
# 161129   ABNAMROMTGEGROUPINC               0                0
# 161130  WASHINGTONMUTUALBANK               0                0
# 161131   WELLSFARGOBANKNA                  0                0
# 161132  COUNTRYWIDE                        0                0
#
#        MonthsInRepayment IsFirstTimeHomebuyer  LTV_Range CreditRange  \
# 0                     52                    0  Very High        Poor
# 1                    144                    0       High        Poor
# 2                     67                    0  Very High        Poor
# 3                     35                    0  Very High        Poor
# 4                     54                    0  Very High        Poor
# ...                  ...                  ...        ...         ...
# 161128                73                    1  Very High        Good
# 161129                 9                    1  Very High        Good
# 161130                68                    1  Very High        Good
# 161131               142                    1  Very High        Good
# 161132                32                    1  Very High        Good
#
#        MIP_Range RepPayRange
# 0         Medium      4-8yrs
# 1            Low    12-16yrs
# 2            Low      4-8yrs
# 3            Low      0-4yrs
# 4            Low      4-8yrs
# ...          ...         ...
# 161128       Low      4-8yrs
# 161129       Low      0-4yrs
# 161130    Medium      4-8yrs
# 161131       Low     8-12yrs
# 161132       Low      0-4yrs
#
# [100000 rows x 33 columns]

# %%
# Convert the date columns to datetime format
df['FirstPaymentDate'] = pd.to_datetime(df['FirstPaymentDate'],format='%Y%m')
df['MaturityDate'] = pd.to_datetime(df['MaturityDate'], format='%Y%m')
# Calculate the difference in months
df['Month_Difference'] = (df['MaturityDate'].dt.to_period('M') - df['FirstPaymentDate'].dt.to_period('M')).apply(lambda x: x.n)

# %%
df["Month_Difference"].value_counts()
# Out:
# Month_Difference
# 359    180402
# 353       278
# 335        87
# 358        51
# 347        47
#         ...
# 321         3
# 301         3
# 303         2
# 302         2
# 360         1
# Name: count, Length: 61, dtype: int64

# %%
df.head(1000)
# Out:
#       CreditScore FirstPaymentDate FirstTimeHomebuyer MaturityDate    MSA  \
# 0               0       1999-02-01                  N   2029-01-01  16974
# 1               0       1999-02-01                  N   2029-01-01  19740
# 2               0       1999-02-01                  N   2029-01-01  29940
# 3               0       1999-02-01                  N   2029-01-01  31084
# 4               0       1999-02-01                  N   2029-01-01  35644
# ...           ...              ...                ...          ...    ...
# 1597          534       1999-03-01                  N   2029-02-01  43340
# 1602          534       1999-04-01                  N   2029-03-01  16974
# 1603          534       1999-04-01                  N   2029-03-01  26620
# 1604          534       1999-04-01                  N   2029-03-01  28140
# 1605          534       1999-04-01                  N   2029-03-01  42044
#
#       MIP  Units Occupancy  OCLTV  DTI  ...          ServicerName  \
# 0      25      1         O     89   27  ...  WASHINGTONMUTUALBANK
# 1       0      1         O     73   17  ...  CHASEHOMEFINANCELLC
# 2       0      1         O     75   16  ...  WASHINGTONMUTUALBANK
# 3       0      1         O     76   14  ...  GMACMTGECORP
# 4       0      1         O     78   18  ...  GMACMTGECORP
# ...   ...    ...       ...    ...  ...  ...                   ...
# 1597    0      1         O     66   52  ...  GMACMTGECORP
# 1602   30      1         O     95   29  ...  Other servicers
# 1603    0      1         O     75   22  ...  Other servicers
# 1604    0      1         O     75   53  ...  GMACMTGECORP
# 1605   25      1         O     89   32  ...  GMACMTGECORP
#
#       EverDelinquent  MonthsDelinquent MonthsInRepayment IsFirstTimeHomebuyer  \
# 0                  0                 0                52                    0
# 1                  0                 0               144                    0
# 2                  0                 0                67                    0
# 3                  0                 0                35                    0
# 4                  0                 0                54                    0
# ...              ...               ...               ...                  ...
# 1597               1                 2                75                    0
# 1602               0                 0                24                    0
# 1603               0                 0                20                    0
# 1604               0                 0                40                    0
# 1605               0                 0                26                    0
#
#       LTV_Range CreditRange MIP_Range RepPayRange Month_Difference
# 0     Very High        Poor    Medium      4-8yrs              359
# 1          High        Poor       Low    12-16yrs              359
# 2     Very High        Poor       Low      4-8yrs              359
# 3     Very High        Poor       Low      0-4yrs              359
# 4     Very High        Poor       Low      4-8yrs              359
# ...         ...         ...       ...         ...              ...
# 1597       High        Poor       Low      4-8yrs              359
# 1602  Very High        Poor    Medium      0-4yrs              359
# 1603  Very High        Poor       Low      0-4yrs              359
# 1604  Very High        Poor       Low      0-4yrs              359
# 1605  Very High        Poor    Medium      0-4yrs              359
#
# [1000 rows x 34 columns]

# %%
def calculate_emi(OrigUPB, OrigInterestRate, OrigLoanTerm):
    r = (OrigInterestRate / 12) / 100  # Convert annual interest rate to monthly rate
    n = OrigLoanTerm  # Total number of monthly installments

    emi = (OrigUPB * r * (1 + r) ** n) / ((1 + r) ** n - 1)
    return round(emi, 2)  # Round the EMI to 2 decimal places
# Calculate EMI and create a new column for EMI
df['monthly_payment'] = calculate_emi(df['OrigUPB'], df['OrigInterestRate'], df['OrigLoanTerm'])

# %%
df["total_payment"] = df['monthly_payment']*df["OrigLoanTerm"]
df['total_payment'] = df['total_payment'].round(2)
df["interest_amount"] = df["total_payment"]-df["OrigUPB"]
df['interest_amount'] = df['interest_amount'].round(2)

# %%
df["monthly_income"] = (df["monthly_payment"]//df["DTI"])* 100
df['monthly_income'] = df['monthly_income'].round(2)

# %%
df["monthly_rate"] = df["OrigInterestRate"]/1200
df['monthly_rate'] = df['monthly_rate'].round(4)

# %%
def principle(monthly_rate,OrigUPB,monthly_payment,MonthsInRepayment):
    for i in range(MonthsInRepayment):
        interest = monthly_rate*OrigUPB
        p=monthly_payment-interest
    return round (p,2)


df["monthly_priciple amount"] = np.vectorize(principle)(df["monthly_rate"],df["OrigUPB"],df["monthly_payment"],df["MonthsInRepayment"])

# %%
def principle(monthly_rate,OrigUPB,monthly_payment,MonthsInRepayment):
    remaining_principal = OrigUPB
    for i in range(MonthsInRepayment):
        interest = monthly_rate*OrigUPB
        p=monthly_payment-interest
        remaining_principal =  remaining_principal- p
    return round (remaining_principal,2)


df["principal_amount_remaining"] = np.vectorize(principle)(df["monthly_rate"],df["OrigUPB"],df["monthly_payment"],df["MonthsInRepayment"])

# %%
def principle(monthly_rate,OrigUPB,monthly_payment,MonthsInRepayment):
    remaining_principal = OrigUPB
    for i in range(MonthsInRepayment):
        interest = monthly_rate*OrigUPB
        p=monthly_payment-interest
        remaining_principal =  remaining_principal- p
        priciple_amount_paid = OrigUPB - remaining_principal
    return round (priciple_amount_paid,2)


df["priciple_amount_paid"] = np.vectorize(principle)(df["monthly_rate"],df["OrigUPB"],df["monthly_payment"],df["MonthsInRepayment"])

# %%
df
# Out:
#         CreditScore FirstPaymentDate FirstTimeHomebuyer MaturityDate    MSA  \
# 0                 0       1999-02-01                  N   2029-01-01  16974
# 1                 0       1999-02-01                  N   2029-01-01  19740
# 2                 0       1999-02-01                  N   2029-01-01  29940
# 3                 0       1999-02-01                  N   2029-01-01  31084
# 4                 0       1999-02-01                  N   2029-01-01  35644
# ...             ...              ...                ...          ...    ...
# 291446          839       1999-03-01                  N   2029-02-01  37964
# 291447          840       2002-10-01                  N   2029-04-01  35644
# 291448          840       2003-04-01                  N   2029-04-01  42044
# 291449          845       1999-04-01                  N   2029-03-01  37964
# 291450          849       1999-03-01                  N   2029-02-01  37964
#
#         MIP  Units Occupancy  OCLTV  DTI  ...  RepPayRange  Month_Difference  \
# 0        25      1         O     89   27  ...       4-8yrs               359
# 1         0      1         O     73   17  ...     12-16yrs               359
# 2         0      1         O     75   16  ...       4-8yrs               359
# 3         0      1         O     76   14  ...       0-4yrs               359
# 4         0      1         O     78   18  ...       4-8yrs               359
# ...     ...    ...       ...    ...  ...  ...          ...               ...
# 291446    0      1         O     60   32  ...       0-4yrs               359
# 291447    0      1         O     73    0  ...       4-8yrs               318
# 291448    0      1         O     73   31  ...       0-4yrs               312
# 291449    0      1         I     80   54  ...       0-4yrs               359
# 291450    0      1         O     47   29  ...       0-4yrs               359
#
#         monthly_payment total_payment interest_amount monthly_income  \
# 0                758.86     273189.60       156189.60         2800.0
# 1                688.95     248022.00       139022.00         4000.0
# 2                578.10     208116.00       120116.00         3600.0
# 3               1051.09     378392.40       218392.40         7500.0
# 4                734.35     264366.00       155366.00         4000.0
# ...                 ...           ...             ...            ...
# 291446           598.77     215557.20       125557.20         1800.0
# 291447          1739.31     554839.89       287839.89            inf
# 291448           530.57     166068.41        79068.41         1700.0
# 291449           585.47     210769.20       122769.20         1000.0
# 291450           465.71     167655.60        97655.60         1600.0
#
#        monthly_rate monthly_priciple amount principal_amount_remaining  \
# 0            0.0056                  103.66                  111609.68
# 1            0.0054                  100.35                   94549.60
# 2            0.0057                   76.50                   82874.50
# 3            0.0057                  139.09                  155131.85
# 4            0.0059                   91.25                  104072.50
# ...             ...                     ...                        ...
# 291446       0.0058                   76.77                   89078.76
# 291447       0.0053                  324.21                  249816.87
# 291448       0.0047                  121.67                   82376.54
# 291449       0.0058                   75.07                   85597.76
# 291450       0.0058                   59.71                   68268.41
#
#        priciple_amount_paid
# 0                   5390.32
# 1                  14450.40
# 2                   5125.50
# 3                   4868.15
# 4                   4927.50
# ...                     ...
# 291446               921.24
# 291447             17183.13
# 291448              4623.46
# 291449              2402.24
# 291450              1731.59
#
# [181686 rows x 42 columns]

# %%
def prepay(dti,income):
    if(dti<40):
        p=income/2
    else:
        p=income*3/4
    return p
df["prepayment"]=np.vectorize(prepay)(df["DTI"],df["monthly_income"]*24)
df["prepayment"]=df["prepayment"]-(df["monthly_payment"]*24)

# %%
df.isnull().sum()
# Out:
# CreditScore                   0
# FirstPaymentDate              0
# FirstTimeHomebuyer            0
# MaturityDate                  0
# MSA                           0
# MIP                           0
# Units                         0
# Occupancy                     0
# OCLTV                         0
# DTI                           0
# OrigUPB                       0
# LTV                           0
# OrigInterestRate              0
# Channel                       0
# PPM                           0
# ProductType                   0
# PropertyState                 0
# PropertyType                  0
# PostalCode                    0
# LoanSeqNum                    0
# LoanPurpose                   0
# OrigLoanTerm                  0
# NumBorrowers                  0
# SellerName                    0
# ServicerName                  0
# EverDelinquent                0
# MonthsDelinquent              0
# MonthsInRepayment             0
# IsFirstTimeHomebuyer          0
# LTV_Range                     0
# CreditRange                   0
# MIP_Range                     0
# RepPayRange                   0
# Month_Difference              0
# monthly_payment               0
# total_payment                 0
# interest_amount               0
# monthly_income                0
# monthly_rate                  0
# monthly_priciple amount       0
# principal_amount_remaining    0
# priciple_amount_paid          0
# prepayment                    0
# dtype: int64

# %%
df
# Out:
#         CreditScore FirstPaymentDate FirstTimeHomebuyer MaturityDate    MSA  \
# 0                 0       1999-02-01                  N   2029-01-01  16974
# 1                 0       1999-02-01                  N   2029-01-01  19740
# 2                 0       1999-02-01                  N   2029-01-01  29940
# 3                 0       1999-02-01                  N   2029-01-01  31084
# 4                 0       1999-02-01                  N   2029-01-01  35644
# ...             ...              ...                ...          ...    ...
# 291446          839       1999-03-01                  N   2029-02-01  37964
# 291447          840       2002-10-01                  N   2029-04-01  35644
# 291448          840       2003-04-01                  N   2029-04-01  42044
# 291449          845       1999-04-01                  N   2029-03-01  37964
# 291450          849       1999-03-01                  N   2029-02-01  37964
#
#         MIP  Units Occupancy  OCLTV  DTI  ...  Month_Difference  \
# 0        25      1         O     89   27  ...               359
# 1         0      1         O     73   17  ...               359
# 2         0      1         O     75   16  ...               359
# 3         0      1         O     76   14  ...               359
# 4         0      1         O     78   18  ...               359
# ...     ...    ...       ...    ...  ...  ...               ...
# 291446    0      1         O     60   32  ...               359
# 291447    0      1         O     73    0  ...               318
# 291448    0      1         O     73   31  ...               312
# 291449    0      1         I     80   54  ...               359
# 291450    0      1         O     47   29  ...               359
#
#         monthly_payment  total_payment interest_amount monthly_income  \
# 0                758.86      273189.60       156189.60         2800.0
# 1                688.95      248022.00       139022.00         4000.0
# 2                578.10      208116.00       120116.00         3600.0
# 3               1051.09      378392.40       218392.40         7500.0
# 4                734.35      264366.00       155366.00         4000.0
# ...                 ...            ...             ...            ...
# 291446           598.77      215557.20       125557.20         1800.0
# 291447          1739.31      554839.89       287839.89            inf
# 291448           530.57      166068.41        79068.41         1700.0
# 291449           585.47      210769.20       122769.20         1000.0
# 291450           465.71      167655.60        97655.60         1600.0
#
#        monthly_rate monthly_priciple amount principal_amount_remaining  \
# 0            0.0056                  103.66                  111609.68
# 1            0.0054                  100.35                   94549.60
# 2            0.0057                   76.50                   82874.50
# 3            0.0057                  139.09                  155131.85
# 4            0.0059                   91.25                  104072.50
# ...             ...                     ...                        ...
# 291446       0.0058                   76.77                   89078.76
# 291447       0.0053                  324.21                  249816.87
# 291448       0.0047                  121.67                   82376.54
# 291449       0.0058                   75.07                   85597.76
# 291450       0.0058                   59.71                   68268.41
#
#        priciple_amount_paid prepayment
# 0                   5390.32   15387.36
# 1                  14450.40   31465.20
# 2                   5125.50   29325.60
# 3                   4868.15   64773.84
# 4                   4927.50   30375.60
# ...                     ...        ...
# 291446               921.24    7229.52
# 291447             17183.13        inf
# 291448              4623.46    7666.32
# 291449              2402.24    3948.72
# 291450              1731.59    8022.96
#
# [181686 rows x 43 columns]

# %%
df.drop(['FirstTimeHomebuyer','LTV','MonthsInRepayment',"CreditScore","FirstPaymentDate","MaturityDate"],axis=1, inplace=True)

# %%
df.drop(['PostalCode','LoanSeqNum',"ProductType"],axis=1, inplace=True)

# %%
df
# Out:
#           MSA  MIP  Units Occupancy  OCLTV  DTI  OrigUPB  OrigInterestRate  \
# 0       16974   25      1         O     89   27   117000             6.750
# 1       19740    0      1         O     73   17   109000             6.500
# 2       29940    0      1         O     75   16    88000             6.875
# 3       31084    0      1         O     76   14   160000             6.875
# 4       35644    0      1         O     78   18   109000             7.125
# ...       ...  ...    ...       ...    ...  ...      ...               ...
# 291446  37964    0      1         O     60   32    90000             7.000
# 291447  35644    0      1         O     73    0   267000             6.375
# 291448  42044    0      1         O     73   31    87000             5.625
# 291449  37964    0      1         I     80   54    88000             7.000
# 291450  37964    0      1         O     47   29    70000             7.000
#
#        Channel PPM  ... Month_Difference monthly_payment total_payment  \
# 0            T   N  ...              359          758.86     273189.60
# 1            R   N  ...              359          688.95     248022.00
# 2            T   N  ...              359          578.10     208116.00
# 3            R   N  ...              359         1051.09     378392.40
# 4            R   N  ...              359          734.35     264366.00
# ...        ...  ..  ...              ...             ...           ...
# 291446       R   N  ...              359          598.77     215557.20
# 291447       C   N  ...              318         1739.31     554839.89
# 291448       R   N  ...              312          530.57     166068.41
# 291449       R   N  ...              359          585.47     210769.20
# 291450       R   N  ...              359          465.71     167655.60
#
#         interest_amount  monthly_income monthly_rate monthly_priciple amount  \
# 0             156189.60          2800.0       0.0056                  103.66
# 1             139022.00          4000.0       0.0054                  100.35
# 2             120116.00          3600.0       0.0057                   76.50
# 3             218392.40          7500.0       0.0057                  139.09
# 4             155366.00          4000.0       0.0059                   91.25
# ...                 ...             ...          ...                     ...
# 291446        125557.20          1800.0       0.0058                   76.77
# 291447        287839.89             inf       0.0053                  324.21
# 291448         79068.41          1700.0       0.0047                  121.67
# 291449        122769.20          1000.0       0.0058                   75.07
# 291450         97655.60          1600.0       0.0058                   59.71
#
#         principal_amount_remaining  priciple_amount_paid  prepayment
# 0                        111609.68               5390.32    15387.36
# 1                         94549.60              14450.40    31465.20
# 2                         82874.50               5125.50    29325.60
# 3                        155131.85               4868.15    64773.84
# 4                        104072.50               4927.50    30375.60
# ...                            ...                   ...         ...
# 291446                    89078.76                921.24     7229.52
# 291447                   249816.87              17183.13         inf
# 291448                    82376.54               4623.46     7666.32
# 291449                    85597.76               2402.24     3948.72
# 291450                    68268.41               1731.59     8022.96
#
# [181686 rows x 34 columns]

# %%
df.head()
# Out:
#      MSA  MIP  Units Occupancy  OCLTV  DTI  OrigUPB  OrigInterestRate Channel  \
# 0  16974   25      1         O     89   27   117000             6.750       T
# 1  19740    0      1         O     73   17   109000             6.500       R
# 2  29940    0      1         O     75   16    88000             6.875       T
# 3  31084    0      1         O     76   14   160000             6.875       R
# 4  35644    0      1         O     78   18   109000             7.125       R
#
#   PPM  ... Month_Difference monthly_payment total_payment  interest_amount  \
# 0   N  ...              359          758.86      273189.6         156189.6
# 1   N  ...              359          688.95      248022.0         139022.0
# 2   N  ...              359          578.10      208116.0         120116.0
# 3   N  ...              359         1051.09      378392.4         218392.4
# 4   N  ...              359          734.35      264366.0         155366.0
#
#    monthly_income monthly_rate monthly_priciple amount  \
# 0          2800.0       0.0056                  103.66
# 1          4000.0       0.0054                  100.35
# 2          3600.0       0.0057                   76.50
# 3          7500.0       0.0057                  139.09
# 4          4000.0       0.0059                   91.25
#
#    principal_amount_remaining  priciple_amount_paid  prepayment
# 0                   111609.68               5390.32    15387.36
# 1                    94549.60              14450.40    31465.20
# 2                    82874.50               5125.50    29325.60
# 3                   155131.85               4868.15    64773.84
# 4                   104072.50               4927.50    30375.60
#
# [5 rows x 34 columns]

# %%
#Label Encoding
df.columns
# Out:
# Index(['MSA', 'MIP', 'Units', 'Occupancy', 'OCLTV', 'DTI', 'OrigUPB',
#        'OrigInterestRate', 'Channel', 'PPM', 'PropertyState', 'PropertyType',
#        'LoanPurpose', 'OrigLoanTerm', 'NumBorrowers', 'SellerName',
#        'ServicerName', 'EverDelinquent', 'MonthsDelinquent',
#        'IsFirstTimeHomebuyer', 'LTV_Range', 'CreditRange', 'MIP_Range',
#        'RepPayRange', 'Month_Difference', 'monthly_payment', 'total_payment',
#        'interest_amount', 'monthly_income', 'monthly_rate',
#        'monthly_priciple amount', 'principal_amount_remaining',
#        'priciple_amount_paid', 'prepayment'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder

# Now you can create an instance of LabelEncoder
encoder = LabelEncoder()

# %%
df['PPM']= encoder.fit_transform(df['PPM'])
df['LoanPurpose']= encoder.fit_transform(df['LoanPurpose'])
df['PropertyState']= encoder.fit_transform(df['PropertyState'])
df['ServicerName']= encoder.fit_transform(df['ServicerName'])
df['PropertyType']= encoder.fit_transform(df['PropertyType'])
df['Channel']= encoder.fit_transform(df['Channel'])
df['SellerName']= encoder.fit_transform(df['SellerName'])
df['LTV_Range']= encoder.fit_transform(df['LTV_Range'])
df['DTI']= encoder.fit_transform(df['DTI'])
df['CreditRange']= encoder.fit_transform(df['CreditRange'])
df['MIP']= encoder.fit_transform(df['MIP'])
df['RepPayRange']= encoder.fit_transform(df['RepPayRange'])
df['Month_Difference']= encoder.fit_transform(df['Month_Difference'])

# %%
df.shape
# Out:
# (181686, 34)

# %%
df.head()
# Out:
#      MSA  MIP  Units Occupancy  OCLTV  DTI  OrigUPB  OrigInterestRate  \
# 0  16974   18      1         O     89   27   117000             6.750
# 1  19740    0      1         O     73   17   109000             6.500
# 2  29940    0      1         O     75   16    88000             6.875
# 3  31084    0      1         O     76   14   160000             6.875
# 4  35644    0      1         O     78   18   109000             7.125
#
#    Channel  PPM  ...  Month_Difference  monthly_payment  total_payment  \
# 0        3    0  ...                59           758.86       273189.6
# 1        2    0  ...                59           688.95       248022.0
# 2        3    0  ...                59           578.10       208116.0
# 3        2    0  ...                59          1051.09       378392.4
# 4        2    0  ...                59           734.35       264366.0
#
#    interest_amount  monthly_income  monthly_rate  monthly_priciple amount  \
# 0         156189.6          2800.0        0.0056                   103.66
# 1         139022.0          4000.0        0.0054                   100.35
# 2         120116.0          3600.0        0.0057                    76.50
# 3         218392.4          7500.0        0.0057                   139.09
# 4         155366.0          4000.0        0.0059                    91.25
#
#    principal_amount_remaining  priciple_amount_paid  prepayment
# 0                   111609.68               5390.32    15387.36
# 1                    94549.60              14450.40    31465.20
# 2                    82874.50               5125.50    29325.60
# 3                   155131.85               4868.15    64773.84
# 4                   104072.50               4927.50    30375.60
#
# [5 rows x 34 columns]

# %% [markdown]
# one hot encoding

# %%
df.columns
# Out:
# Index(['MSA', 'MIP', 'Units', 'Occupancy', 'OCLTV', 'DTI', 'OrigUPB',
#        'OrigInterestRate', 'Channel', 'PPM', 'PropertyState', 'PropertyType',
#        'LoanPurpose', 'OrigLoanTerm', 'NumBorrowers', 'SellerName',
#        'ServicerName', 'EverDelinquent', 'MonthsDelinquent',
#        'IsFirstTimeHomebuyer', 'LTV_Range', 'CreditRange', 'MIP_Range',
#        'RepPayRange', 'Month_Difference', 'monthly_payment', 'total_payment',
#        'interest_amount', 'monthly_income', 'monthly_rate',
#        'monthly_priciple amount', 'principal_amount_remaining',
#        'priciple_amount_paid', 'prepayment'],
#       dtype='object')

# %%
df_city = pd.get_dummies(df['Occupancy'],drop_first = True)

# %%
df=pd.concat([df,df_city],axis=1)

# %%
# Display the encoded DataFrame
df.head()
# Out:
#      MSA  MIP  Units Occupancy  OCLTV  DTI  OrigUPB  OrigInterestRate  \
# 0  16974   18      1         O     89   27   117000             6.750
# 1  19740    0      1         O     73   17   109000             6.500
# 2  29940    0      1         O     75   16    88000             6.875
# 3  31084    0      1         O     76   14   160000             6.875
# 4  35644    0      1         O     78   18   109000             7.125
#
#    Channel  PPM  ...  total_payment  interest_amount  monthly_income  \
# 0        3    0  ...       273189.6         156189.6          2800.0
# 1        2    0  ...       248022.0         139022.0          4000.0
# 2        3    0  ...       208116.0         120116.0          3600.0
# 3        2    0  ...       378392.4         218392.4          7500.0
# 4        2    0  ...       264366.0         155366.0          4000.0
#
#    monthly_rate  monthly_priciple amount  principal_amount_remaining  \
# 0        0.0056                   103.66                   111609.68
# 1        0.0054                   100.35                    94549.60
# 2        0.0057                    76.50                    82874.50
# 3        0.0057                   139.09                   155131.85
# 4        0.0059                    91.25                   104072.50
#
#    priciple_amount_paid  prepayment     O      S
# 0               5390.32    15387.36  True  False
# 1              14450.40    31465.20  True  False
# 2               5125.50    29325.60  True  False
# 3               4868.15    64773.84  True  False
# 4               4927.50    30375.60  True  False
#
# [5 rows x 36 columns]

# %%
df.drop('Occupancy',axis=1,inplace=True)

# %%
df.head()
# Out:
#      MSA  MIP  Units  OCLTV  DTI  OrigUPB  OrigInterestRate  Channel  PPM  \
# 0  16974   18      1     89   27   117000             6.750        3    0
# 1  19740    0      1     73   17   109000             6.500        2    0
# 2  29940    0      1     75   16    88000             6.875        3    0
# 3  31084    0      1     76   14   160000             6.875        2    0
# 4  35644    0      1     78   18   109000             7.125        2    0
#
#    PropertyState  ...  total_payment  interest_amount  monthly_income  \
# 0             14  ...       273189.6         156189.6          2800.0
# 1              5  ...       248022.0         139022.0          4000.0
# 2             16  ...       208116.0         120116.0          3600.0
# 3              4  ...       378392.4         218392.4          7500.0
# 4             31  ...       264366.0         155366.0          4000.0
#
#    monthly_rate  monthly_priciple amount  principal_amount_remaining  \
# 0        0.0056                   103.66                   111609.68
# 1        0.0054                   100.35                    94549.60
# 2        0.0057                    76.50                    82874.50
# 3        0.0057                   139.09                   155131.85
# 4        0.0059                    91.25                   104072.50
#
#    priciple_amount_paid  prepayment     O      S
# 0               5390.32    15387.36  True  False
# 1              14450.40    31465.20  True  False
# 2               5125.50    29325.60  True  False
# 3               4868.15    64773.84  True  False
# 4               4927.50    30375.60  True  False
#
# [5 rows x 35 columns]

# %%
df = df[~df.isin([np.inf, -np.inf]).any(axis=1)]
df.shape
# Out:
# (179466, 35)

# %% [markdown]
# Feature Selection

# %%
corrmat = df.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
#plot heat map
g=sns.heatmap(df[top_corr_features].corr(),annot=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-97-358ed6157ea4> in <cell line: 1>()
# ----> 1 corrmat = df.corr()
#       2 top_corr_features = corrmat.index
#       3 plt.figure(figsize=(20,20))
#       4 #plot heat map
#       5 g=sns.heatmap(df[top_corr_features].corr(),annot=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   10702         cols = data.columns
#   10703         idx = cols.copy()
# > 10704         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10705
#   10706         if method == "pearson":
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1887         if dtype is not None:
#    1888             dtype = np.dtype(dtype)
# -> 1889         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1890         if result.dtype is not dtype:
#    1891             result = np.array(result, dtype=dtype, copy=False)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in as_array(self, dtype, copy, na_value)
#    1654                 arr.flags.writeable = False
#    1655         else:
# -> 1656             arr = self._interleave(dtype=dtype, na_value=na_value)
#    1657             # The underlying data was copied within _interleave, so no need
#    1658             # to further copy if copy=True or setting na_value
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in _interleave(self, dtype, na_value)
#    1713             else:
#    1714                 arr = blk.get_values(dtype)
# -> 1715             result[rl.indexer] = arr
#    1716             itemmask[rl.indexer] = 1
#    1717
#
# ValueError: could not convert string to float: 'Medium'

# %%
# Filter the DataFrame to include only numerical columns
df_numeric = df.select_dtypes(include=[np.number])

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Calculate the correlation matrix for the numerical columns
corrmat = df_numeric.corr()

# Get the correlation matrix's index
top_corr_features = corrmat.index

# Plot the heatmap
plt.figure(figsize=(20, 20))
g = sns.heatmap(df_numeric[top_corr_features].corr(), annot=True, cmap='coolwarm')
plt.show()

# %%
df.drop(['OrigLoanTerm'],axis=1, inplace=True)
df.drop(['OrigUPB'],axis=1, inplace=True)
df.drop(['OrigInterestRate'],axis=1, inplace=True)

# %%
x=df.drop("prepayment",axis=1)
y=df["prepayment"]

# %%
x
# Out:
#           MSA  MIP  Units  OCLTV  DTI  Channel  PPM  PropertyState  \
# 0       16974   18      1     89   27        3    0             14
# 1       19740    0      1     73   17        2    0              5
# 2       29940    0      1     75   16        3    0             16
# 3       31084    0      1     76   14        2    0              4
# 4       35644    0      1     78   18        2    0             31
# ...       ...  ...    ...    ...  ...      ...  ...            ...
# 291445  19740    0      1     75   51        3    0              5
# 291446  37964    0      1     60   32        2    0             38
# 291448  42044    0      1     73   31        2    0              4
# 291449  37964    0      1     80   54        2    0             38
# 291450  37964    0      1     47   29        2    0             38
#
#         PropertyType  LoanPurpose  ...  monthly_payment  total_payment  \
# 0                  5            2  ...           758.86      273189.60
# 1                  5            1  ...           688.95      248022.00
# 2                  5            1  ...           578.10      208116.00
# 3                  5            1  ...          1051.09      378392.40
# 4                  5            1  ...           734.35      264366.00
# ...              ...          ...  ...              ...            ...
# 291445             0            2  ...           227.47       81889.20
# 291446             5            1  ...           598.77      215557.20
# 291448             5            1  ...           530.57      166068.41
# 291449             5            2  ...           585.47      210769.20
# 291450             5            2  ...           465.71      167655.60
#
#         interest_amount  monthly_income  monthly_rate  \
# 0             156189.60          2800.0        0.0056
# 1             139022.00          4000.0        0.0054
# 2             120116.00          3600.0        0.0057
# 3             218392.40          7500.0        0.0057
# 4             155366.00          4000.0        0.0059
# ...                 ...             ...           ...
# 291445         50889.20           400.0        0.0067
# 291446        125557.20          1800.0        0.0058
# 291448         79068.41          1700.0        0.0047
# 291449        122769.20          1000.0        0.0058
# 291450         97655.60          1600.0        0.0058
#
#         monthly_priciple amount  principal_amount_remaining  \
# 0                        103.66                   111609.68
# 1                        100.35                    94549.60
# 2                         76.50                    82874.50
# 3                        139.09                   155131.85
# 4                         91.25                   104072.50
# ...                         ...                         ...
# 291445                    19.77                    29971.96
# 291446                    76.77                    89078.76
# 291448                   121.67                    82376.54
# 291449                    75.07                    85597.76
# 291450                    59.71                    68268.41
#
#         priciple_amount_paid      O      S
# 0                    5390.32   True  False
# 1                   14450.40   True  False
# 2                    5125.50   True  False
# 3                    4868.15   True  False
# 4                    4927.50   True  False
# ...                      ...    ...    ...
# 291445               1028.04  False  False
# 291446                921.24   True  False
# 291448               4623.46   True  False
# 291449               2402.24  False  False
# 291450               1731.59   True  False
#
# [179466 rows x 31 columns]

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# One-Hot Encoding for nominal categorical variables
X_encoded = pd.get_dummies(x, drop_first=True)

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression

# Assuming 'y' is your target variable and 'X_encoded' is the feature matrix after encoding

# Create a Linear Regression model
model = LinearRegression()

# Create RFE with the Linear Regression model and specify the desired number of features
rfe = RFE(model, n_features_to_select=20)  # Change the 'n_features_to_select' as per your requirement

# Fit RFE on the data
rfe.fit(X_encoded, y)

# Get the selected features
selected_features = X_encoded.columns[rfe.support_]

# Print the selected features
print("Selected Features:", selected_features)
# Out:
# Selected Features: Index(['Units', 'OCLTV', 'DTI', 'Channel', 'PPM', 'PropertyType',
#        'NumBorrowers', 'EverDelinquent', 'IsFirstTimeHomebuyer', 'LTV_Range',
#        'CreditRange', 'total_payment', 'interest_amount', 'monthly_rate',
#        'principal_amount_remaining', 'priciple_amount_paid', 'O', 'S',
#        'MIP_Range_Low', 'MIP_Range_Medium'],
#       dtype='object')

# %%
# List of selected columns
selected_columns = ['Units', 'OCLTV', 'DTI', 'Channel', 'PPM', 'PropertyType',
       'NumBorrowers', 'ServicerName', 'EverDelinquent',
       'IsFirstTimeHomebuyer', 'CreditRange', 'monthly_payment',
       'total_payment', 'interest_amount', 'monthly_income', 'monthly_rate',
       'principal_amount_remaining', 'priciple_amount_paid', 'O', 'S']

# Create a new DataFrame with only the selected columns
new_dataset = x[selected_columns].copy()

# Display the new DataFrame
print(new_dataset)
# Out:
#         Units  OCLTV  DTI  Channel  PPM  PropertyType  NumBorrowers  \
# 0           1     89   27        3    0             5             2
# 1           1     73   17        2    0             5             1
# 2           1     75   16        3    0             5             2
# 3           1     76   14        2    0             5             2
# 4           1     78   18        2    0             5             2
# ...       ...    ...  ...      ...  ...           ...           ...
# 291445      1     75   51        3    0             0             1
# 291446      1     60   32        2    0             5             2
# 291448      1     73   31        2    0             5             1
# 291449      1     80   54        2    0             5             2
# 291450      1     47   29        2    0             5             2
#
#         ServicerName  EverDelinquent  IsFirstTimeHomebuyer  CreditRange  \
# 0                 17               0                     0            3
# 1                  3               0                     0            3
# 2                 17               0                     0            3
# 3                 10               0                     0            3
# 4                 10               0                     0            3
# ...              ...             ...                   ...          ...
# 291445            14               0                     0            0
# 291446            14               0                     0            0
# 291448            14               0                     0            0
# 291449            14               0                     0            0
# 291450            14               0                     0            0
#
#         monthly_payment  total_payment  interest_amount  monthly_income  \
# 0                758.86      273189.60        156189.60          2800.0
# 1                688.95      248022.00        139022.00          4000.0
# 2                578.10      208116.00        120116.00          3600.0
# 3               1051.09      378392.40        218392.40          7500.0
# 4                734.35      264366.00        155366.00          4000.0
# ...                 ...            ...              ...             ...
# 291445           227.47       81889.20         50889.20           400.0
# 291446           598.77      215557.20        125557.20          1800.0
# 291448           530.57      166068.41         79068.41          1700.0
# 291449           585.47      210769.20        122769.20          1000.0
# 291450           465.71      167655.60         97655.60          1600.0
#
#         monthly_rate  principal_amount_remaining  priciple_amount_paid      O  \
# 0             0.0056                   111609.68               5390.32   True
# 1             0.0054                    94549.60              14450.40   True
# 2             0.0057                    82874.50               5125.50   True
# 3             0.0057                   155131.85               4868.15   True
# 4             0.0059                   104072.50               4927.50   True
# ...              ...                         ...                   ...    ...
# 291445        0.0067                    29971.96               1028.04  False
# 291446        0.0058                    89078.76                921.24   True
# 291448        0.0047                    82376.54               4623.46   True
# 291449        0.0058                    85597.76               2402.24  False
# 291450        0.0058                    68268.41               1731.59   True
#
#             S
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# ...       ...
# 291445  False
# 291446  False
# 291448  False
# 291449  False
# 291450  False
#
# [179466 rows x 20 columns]

# %%
# Check the data types of each column
print(new_dataset.dtypes)
# Out:
# Units                           int64
# OCLTV                           int64
# DTI                             int64
# Channel                         int64
# PPM                             int64
# PropertyType                    int64
# NumBorrowers                    int64
# ServicerName                    int64
# EverDelinquent                  int64
# IsFirstTimeHomebuyer            int64
# CreditRange                     int64
# monthly_payment               float64
# total_payment                 float64
# interest_amount               float64
# monthly_income                float64
# monthly_rate                  float64
# principal_amount_remaining    float64
# priciple_amount_paid          float64
# O                                bool
# S                                bool
# dtype: object

# %%
non_numeric_columns = new_dataset.select_dtypes(exclude=[np.number]).columns
print("Non-numeric columns:", non_numeric_columns)
# Out:
# Non-numeric columns: Index(['O', 'S'], dtype='object')

# %%
for col in non_numeric_columns:
    new_dataset[col] = pd.to_numeric(new_dataset[col], errors='coerce')

# %%
# Replace infinite values with NaN
new_dataset.replace([np.inf, -np.inf], np.nan, inplace=True)

# Check for NaN values
print(new_dataset.isnull().sum())

# Drop rows with NaN values
new_dataset.dropna(inplace=True)
# Out:
# Units                         0
# OCLTV                         0
# DTI                           0
# Channel                       0
# PPM                           0
# PropertyType                  0
# NumBorrowers                  0
# ServicerName                  0
# EverDelinquent                0
# IsFirstTimeHomebuyer          0
# CreditRange                   0
# monthly_payment               0
# total_payment                 0
# interest_amount               0
# monthly_income                0
# monthly_rate                  0
# principal_amount_remaining    0
# priciple_amount_paid          0
# O                             0
# S                             0
# dtype: int64

# %%
print(new_dataset.nunique())
# Out:
# Units                             5
# OCLTV                           102
# DTI                              65
# Channel                           4
# PPM                               2
# PropertyType                      7
# NumBorrowers                      2
# ServicerName                     20
# EverDelinquent                    2
# IsFirstTimeHomebuyer              2
# CreditRange                       4
# monthly_payment                6747
# total_payment                  6789
# interest_amount                6847
# monthly_income                  365
# monthly_rate                     46
# principal_amount_remaining    99860
# priciple_amount_paid          82329
# O                                 2
# S                                 2
# dtype: int64

# %%
print(new_dataset.head())
# Out:
#    Units  OCLTV  DTI  Channel  PPM  PropertyType  NumBorrowers  ServicerName  \
# 0      1     89   27        3    0             5             2            17
# 1      1     73   17        2    0             5             1             3
# 2      1     75   16        3    0             5             2            17
# 3      1     76   14        2    0             5             2            10
# 4      1     78   18        2    0             5             2            10
#
#    EverDelinquent  IsFirstTimeHomebuyer  CreditRange  monthly_payment  \
# 0               0                     0            3           758.86
# 1               0                     0            3           688.95
# 2               0                     0            3           578.10
# 3               0                     0            3          1051.09
# 4               0                     0            3           734.35
#
#    total_payment  interest_amount  monthly_income  monthly_rate  \
# 0       273189.6         156189.6          2800.0        0.0056
# 1       248022.0         139022.0          4000.0        0.0054
# 2       208116.0         120116.0          3600.0        0.0057
# 3       378392.4         218392.4          7500.0        0.0057
# 4       264366.0         155366.0          4000.0        0.0059
#
#    principal_amount_remaining  priciple_amount_paid     O      S
# 0                   111609.68               5390.32  True  False
# 1                    94549.60              14450.40  True  False
# 2                    82874.50               5125.50  True  False
# 3                   155131.85               4868.15  True  False
# 4                   104072.50               4927.50  True  False

# %%
subset = new_dataset.iloc[:, :10]  # Select the first 10 columns as an example
vif_data = pd.DataFrame()
vif_data['Variable'] = subset.columns
vif_data['VIF'] = [variance_inflation_factor(subset.values, i) for i in range(subset.shape[1])]
print(vif_data)
# Out:
#                Variable        VIF
# 0                 Units  26.910772
# 1                 OCLTV  24.381049
# 2                   DTI   9.519758
# 3               Channel  22.178889
# 4                   PPM   1.030955
# 5          PropertyType  13.798525
# 6          NumBorrowers  11.937228
# 7          ServicerName   3.721342
# 8        EverDelinquent   1.253882
# 9  IsFirstTimeHomebuyer   1.273176

# %%
x1=new_dataset.drop(["total_payment","interest_amount","principal_amount_remaining","priciple_amount_paid"],axis=1)

# %%
vif_data = pd.DataFrame()
vif_data['Variable'] = x1.columns
vif_data['VIF'] = [variance_inflation_factor(x1.values, i) for i in range(x1.shape[1])]

# Display the VIF DataFrame
print(vif_data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-122-f73a9699bf09> in <cell line: 3>()
#       1 vif_data = pd.DataFrame()
#       2 vif_data['Variable'] = x1.columns
# ----> 3 vif_data['VIF'] = [variance_inflation_factor(x1.values, i) for i in range(x1.shape[1])]
#       4
#       5 # Display the VIF DataFrame
#
# <ipython-input-122-f73a9699bf09> in <listcomp>(.0)
#       1 vif_data = pd.DataFrame()
#       2 vif_data['Variable'] = x1.columns
# ----> 3 vif_data['VIF'] = [variance_inflation_factor(x1.values, i) for i in range(x1.shape[1])]
#       4
#       5 # Display the VIF DataFrame
#
# /usr/local/lib/python3.10/dist-packages/statsmodels/stats/outliers_influence.py in variance_inflation_factor(exog, exog_idx)
#     194     mask = np.arange(k_vars) != exog_idx
#     195     x_noti = exog[:, mask]
# --> 196     r_squared_i = OLS(x_i, x_noti).fit().rsquared
#     197     vif = 1. / (1. - r_squared_i)
#     198     return vif
#
# /usr/local/lib/python3.10/dist-packages/statsmodels/regression/linear_model.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#     922                    "An exception will be raised in the next version.")
#     923             warnings.warn(msg, ValueWarning)
# --> 924         super().__init__(endog, exog, missing=missing,
#     925                                   hasconst=hasconst, **kwargs)
#     926         if "weights" in self._init_keys:
#
# /usr/local/lib/python3.10/dist-packages/statsmodels/regression/linear_model.py in __init__(self, endog, exog, weights, missing, hasconst, **kwargs)
#     747         else:
#     748             weights = weights.squeeze()
# --> 749         super().__init__(endog, exog, missing=missing,
#     750                                   weights=weights, hasconst=hasconst, **kwargs)
#     751         nobs = self.exog.shape[0]
#
# /usr/local/lib/python3.10/dist-packages/statsmodels/regression/linear_model.py in __init__(self, endog, exog, **kwargs)
#     201     """
#     202     def __init__(self, endog, exog, **kwargs):
# --> 203         super().__init__(endog, exog, **kwargs)
#     204         self.pinv_wexog: Float64Array | None = None
#     205         self._data_attr.extend(['pinv_wexog', 'wendog', 'wexog', 'weights'])
#
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py in __init__(self, endog, exog, **kwargs)
#     268
#     269     def __init__(self, endog, exog=None, **kwargs):
# --> 270         super().__init__(endog, exog, **kwargs)
#     271         self.initialize()
#     272
#
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py in __init__(self, endog, exog, **kwargs)
#      93         missing = kwargs.pop('missing', 'none')
#      94         hasconst = kwargs.pop('hasconst', None)
# ---> 95         self.data = self._handle_data(endog, exog, missing, hasconst,
#      96                                       **kwargs)
#      97         self.k_constant = self.data.k_constant
#
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py in _handle_data(self, endog, exog, missing, hasconst, **kwargs)
#     133
#     134     def _handle_data(self, endog, exog, missing, hasconst, **kwargs):
# --> 135         data = handle_data(endog, exog, missing, hasconst, **kwargs)
#     136         # kwargs arrays could have changed, easier to just attach here
#     137         for key in kwargs:
#
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/data.py in handle_data(endog, exog, missing, hasconst, **kwargs)
#     673
#     674     klass = handle_data_class_factory(endog, exog)
# --> 675     return klass(endog, exog=exog, missing=missing, hasconst=hasconst,
#     676                  **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/data.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#      86         self.const_idx = None
#      87         self.k_constant = 0
# ---> 88         self._handle_constant(hasconst)
#      89         self._check_integrity()
#      90         self._cache = {}
#
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/data.py in _handle_constant(self, hasconst)
#     131             check_implicit = False
#     132             exog_max = np.max(self.exog, axis=0)
# --> 133             if not np.isfinite(exog_max).all():
#     134                 raise MissingDataError('exog contains inf or nans')
#     135             exog_min = np.min(self.exog, axis=0)
#
# TypeError: ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
